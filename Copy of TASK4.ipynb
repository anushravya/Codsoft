# %% [markdown]
# #SALES PREDICTION USING PYTHON

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, r2_score

# %% [markdown]
# IMPORTING DATASET

# %%
df = pd.read_csv("advertising.csv")
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.shape
# Out:
# (200, 4)

# %% [markdown]
# DATA VISUALIZATION

# %%
sns.pairplot(df, x_vars = ['TV', 'Radio', 'Newspaper'], y_vars = 'Sales', kind='scatter')
plt.show()

# %% [markdown]
# HISTOGRAMS

# %%
df['TV'].plot.hist(bins = 10, color = 'cyan', xlabel= 'TV')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Radio'].plot.hist(bins = 10, color = 'cyan', xlabel= 'Radio')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Newspaper'].plot.hist(bins = 10, color = 'cyan', xlabel= 'Newspaper')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# HISTOGRAM OBSERVATION:  The majority sales is the result of low advertising cost in newspaper

# %% [markdown]
# HEATMAP

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# sales highly corealted with the TV...
# lets train model using linear regrssion as it is corelated with only one variable TV

# %%
print("x_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# x_train shape: (140, 1)
# y_train shape: (140, 1)

# %%
X = df[['TV']]  # Features
y = df[['Sales']]  # Target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
res = model.predict(X_test)
print(res)
# Out:
# [[18.00786089]
#  [11.36658465]
#  [11.06117479]
#  [ 9.39530282]
#  [15.09258495]
#  [20.14017701]
#  [16.10876685]
#  [17.05276096]
#  [17.37482954]
#  [ 7.56284366]
#  [11.09449223]
#  [18.29661203]
#  [10.03388707]
#  [ 7.95154712]
#  [ 7.64058435]
#  [13.18238509]
#  [16.95280864]
#  [22.27804603]
#  [ 7.95710002]
#  [19.04070151]
#  [ 8.00152327]
#  [11.81637008]
#  [ 7.90712386]
#  [ 9.68960687]
#  [19.14620673]
#  [ 8.40133255]
#  [15.60900526]
#  [14.84825706]
#  [12.2550497 ]
#  [18.92964338]
#  [13.35452519]
#  [20.84539614]
#  [22.88331285]
#  [ 7.99041746]
#  [17.64136906]
#  [19.1184422 ]
#  [21.00643043]
#  [17.18047781]
#  [15.98105   ]
#  [10.988987  ]
#  [10.37261437]
#  [22.50016229]
#  [11.25552652]
#  [21.6616734 ]
#  [19.59043926]
#  [16.04768487]
#  [16.74179819]
#  [19.26281777]
#  [17.88569694]
#  [13.01024499]
#  [14.65945824]
#  [19.45161659]
#  [23.21648724]
#  [14.75941055]
#  [11.10559804]
#  [11.67199451]
#  [10.58362482]
#  [22.28915184]
# ...

# %%
plt.plot(res)

# %%
model.coef_
# Out:
# array([[0.05552907]])

# %%
model.intercept_
# Out:
# array([6.91315359])

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, 7.20655455 + 0.05483488 * X_test, 'r', color = 'yellow' )
plt.show
# below showing solution concludes that the sales using advertising platform datasets successfully able to predict
# Out:
# <ipython-input-139-e6404f633b85>:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r" (-> color=(1.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(X_test, 7.20655455 + 0.05483488 * X_test, 'r', color = 'yellow' )
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print("Mean square error of LinearRegression is {}".format(mean_squared_error(y_test, res)))
# Out:
# Mean square error of LinearRegression is 5.7329278499817535

# %%
print("Root mean squared error of LinearRegression is {}".format(np.sqrt(mean_squared_error(y_test,res))))
# Out:
# Root mean squared error of LinearRegression is 2.394353326053144

# %%
print("Mean absolute error is {}".format(mean_absolute_error(y_test, res)))
# Out:
# Mean absolute error is 1.8010062252975279

# %%
print('R2 score: {}'. format (r2_score(y_test , res )))
# Out:
# R2 score: 0.7895382693709685
